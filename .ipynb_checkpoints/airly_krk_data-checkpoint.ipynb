# %%
import pandas as pd

# %% [markdown]
# # Dane jako dataframe

# %%
history = pd.read_csv("data/full_sensor_data.csv", parse_dates=True, index_col="UTC time")
history.head()
# Out:
#                      3_temperature  3_humidity  3_pressure  3_pm1  3_pm25  \
# UTC time
# 2017-01-01 00:00:00            NaN         NaN         NaN    NaN     NaN
# 2017-01-01 01:00:00            NaN         NaN         NaN    NaN     NaN
# 2017-01-01 02:00:00            NaN         NaN         NaN    NaN     NaN
# 2017-01-01 03:00:00            NaN         NaN         NaN    NaN     NaN
# 2017-01-01 04:00:00            NaN         NaN         NaN    NaN     NaN
#
#                      3_pm10  140_temperature  140_humidity  140_pressure  \
# UTC time
# 2017-01-01 00:00:00     NaN              NaN           NaN           NaN
# 2017-01-01 01:00:00     NaN              NaN           NaN           NaN
# 2017-01-01 02:00:00     NaN              NaN           NaN           NaN
# 2017-01-01 03:00:00     NaN              NaN           NaN           NaN
# 2017-01-01 04:00:00     NaN              NaN           NaN           NaN
#
#                      140_pm1  ...  857_pressure  857_pm1  857_pm25  857_pm10  \
# UTC time                      ...
# 2017-01-01 00:00:00      NaN  ...           NaN      NaN       NaN       NaN
# 2017-01-01 01:00:00      NaN  ...           NaN      NaN       NaN       NaN
# 2017-01-01 02:00:00      NaN  ...           NaN      NaN       NaN       NaN
# 2017-01-01 03:00:00      NaN  ...           NaN      NaN       NaN       NaN
# 2017-01-01 04:00:00      NaN  ...           NaN      NaN       NaN       NaN
#
#                      895_temperature  895_humidity  895_pressure  895_pm1  \
# UTC time
# 2017-01-01 00:00:00              NaN           NaN           NaN      NaN
# 2017-01-01 01:00:00              NaN           NaN           NaN      NaN
# 2017-01-01 02:00:00              NaN           NaN           NaN      NaN
# 2017-01-01 03:00:00              NaN           NaN           NaN      NaN
# 2017-01-01 04:00:00              NaN           NaN           NaN      NaN
#
#                      895_pm25  895_pm10
# UTC time
# 2017-01-01 00:00:00       NaN       NaN
# 2017-01-01 01:00:00       NaN       NaN
# 2017-01-01 02:00:00       NaN       NaN
# 2017-01-01 03:00:00       NaN       NaN
# 2017-01-01 04:00:00       NaN       NaN
#
# [5 rows x 336 columns]

# %%
history.describe()
# Out:
#        3_temperature  3_humidity     3_pressure        3_pm1       3_pm25  \
# count     206.000000  206.000000    1178.000000  1235.000000  1235.000000
# mean       -5.131068   74.718447  101652.880306    70.830769    75.454251
# std         2.174645    9.939247    1020.704947    54.853035    66.299222
# min        -9.000000   38.000000   99160.000000     2.000000     0.000000
# 25%        -7.000000   69.000000  100828.500000    33.000000    30.000000
# 50%        -6.000000   77.000000  101726.000000    50.000000    52.000000
# 75%        -4.000000   82.000000  102352.000000   101.000000   107.500000
# max         2.000000   92.000000  103619.000000   249.000000   314.000000
#
#             3_pm10  140_temperature  140_humidity   140_pressure      140_pm1  \
# count  1235.000000      6506.000000   6506.000000    6683.000000  6631.000000
# mean    112.540891        11.464494     80.271288  101639.084842    26.537023
# std      89.265573         7.630920     17.167440     653.937345    19.283222
# min       3.000000        -6.000000     21.000000   98374.000000     0.000000
# 25%      52.000000         6.000000     70.000000  101291.000000    13.000000
# 50%      87.000000        11.000000     86.000000  101666.000000    23.000000
# 75%     153.000000        17.000000     93.000000  102064.000000    34.000000
# max     440.000000        37.000000    115.000000  103155.000000   160.000000
#
#        ...   857_pressure      857_pm1     857_pm25     857_pm10  \
# count  ...    2653.000000  2653.000000  2653.000000  2653.000000
# mean   ...  101591.979269    29.469280    31.978892    65.852997
# std    ...     809.559197    21.697085    27.709362    56.194746
# min    ...   98372.000000     0.000000     0.000000     0.000000
# 25%    ...  101116.000000    15.000000    14.000000    27.000000
# 50%    ...  101614.000000    25.000000    25.000000    53.000000
# 75%    ...  102207.000000    37.000000    41.000000    85.000000
# max    ...  103146.000000   151.000000   190.000000   373.000000
#
#        895_temperature  895_humidity   895_pressure      895_pm1     895_pm25  \
# count      5443.000000   5443.000000    6337.000000  6337.000000  6337.000000
# mean         10.660665     79.759691  101660.566672    23.879754    23.922519
# std           7.864320     19.397843     649.831280    16.803287    20.897541
# min          -7.000000     18.000000   98433.000000     0.000000     0.000000
# 25%           4.000000     69.000000  101328.000000    13.000000    11.000000
# 50%          10.000000     85.000000  101686.000000    21.000000    19.000000
# 75%          16.000000     92.000000  102079.000000    29.000000    30.000000
# max          34.000000    134.000000  103199.000000   132.000000   159.000000
#
#           895_pm10
# count  6337.000000
# mean     41.092788
# std      32.908029
# min       0.000000
# 25%      18.000000
# 50%      33.000000
# 75%      54.000000
# max     239.000000
#
# [8 rows x 336 columns]

# %%
len(history)
# Out:
# 8593

# %% [markdown]
# # Kolumny, sensory

# %%
columns = history.columns.to_list()
print(columns[:15])
# Out:
# ['3_temperature', '3_humidity', '3_pressure', '3_pm1', '3_pm25', '3_pm10', '140_temperature', '140_humidity', '140_pressure', '140_pm1', '140_pm25', '140_pm10', '142_temperature', '142_humidity', '142_pressure']

# %%
sensors = list(set([int(column.split("_")[0]) for column in history.columns]))
print(sensors)
# Out:
# [3, 263, 140, 142, 147, 808, 169, 170, 171, 172, 173, 174, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 187, 189, 192, 194, 195, 196, 201, 202, 203, 204, 205, 713, 208, 209, 210, 211, 212, 213, 214, 215, 216, 857, 218, 219, 220, 221, 222, 223, 225, 226, 227, 228, 622, 895]

# %%
def get_sensor_columns(sensor_id: int):
    return [ column for column in columns if column.startswith(str(sensor_id))]

get_sensor_columns(142)

# %%
pd.set_option('display.max_rows', 500)
print(history.isna().sum())
# Out:
# 3_temperature      8387
# 3_humidity         8387
# 3_pressure         7415
# 3_pm1              7358
# 3_pm25             7358
# 3_pm10             7358
# 140_temperature    2087
# 140_humidity       2087
# 140_pressure       1910
# 140_pm1            1962
# 140_pm25           1962
# 140_pm10           1962
# 142_temperature    6527
# 142_humidity       6528
# 142_pressure       6552
# 142_pm1            6603
# 142_pm25           6603
# 142_pm10           6603
# 147_temperature    6292
# 147_humidity       6294
# 147_pressure        653
# 147_pm1             628
# 147_pm25            628
# 147_pm10            628
# 169_temperature     331
# 169_humidity        333
# 169_pressure        356
# 169_pm1             332
# 169_pm25            331
# 169_pm10            331
# 170_temperature     133
# 170_humidity        134
# 170_pressure        158
# 170_pm1             133
# 170_pm25            133
# 170_pm10            133
# 171_temperature      79
# 171_humidity         81
# 171_pressure        104
# 171_pm1              79
# 171_pm25             79
# 171_pm10             79
# 172_temperature    6997
# 172_humidity       6997
# 172_pressure        230
# 172_pm1             205
# 172_pm25            205
# 172_pm10            205
# 173_temperature     401
# 173_humidity        403
# 173_pressure        119
# 173_pm1              94
# 173_pm25             94
# 173_pm10             94
# 174_temperature    1208
# 174_humidity       1210
# 174_pressure       1233
# 174_pm1            1208
# 174_pm25           1208
# 174_pm10           1208
# 176_temperature      56
# 176_humidity         58
# 176_pressure       6854
# 176_pm1              56
# 176_pm25             56
# 176_pm10             56
# 177_temperature     818
# 177_humidity        820
# 177_pressure       3045
# 177_pm1             818
# 177_pm25            818
# 177_pm10            818
# 178_temperature    6617
# 178_humidity       6617
# 178_pressure       8593
# 178_pm1            6588
# 178_pm25           6588
# 178_pm10           6588
# 179_temperature     141
# 179_humidity        143
# 179_pressure       7020
# 179_pm1             141
# 179_pm25            141
# 179_pm10            141
# 180_temperature      33
# 180_humidity         34
# 180_pressure       6855
# 180_pm1              32
# 180_pm25             32
# 180_pm10             32
# 181_temperature     227
# 181_humidity        229
# 181_pressure       6859
# 181_pm1             227
# 181_pm25            227
# 181_pm10            227
# 182_temperature    1064
# 182_humidity       1067
# 182_pressure       6892
# 182_pm1            1058
# 182_pm25           1058
# 182_pm10           1058
# 183_temperature     470
# 183_humidity        472
# 183_pressure       7639
# 183_pm1             466
# 183_pm25            466
# 183_pm10            466
# 184_temperature     298
# 184_humidity        300
# 184_pressure       6860
# 184_pm1             295
# 184_pm25            295
# 184_pm10            295
# 185_temperature     734
# 185_humidity        737
# 185_pressure       7135
# 185_pm1             724
# 185_pm25            724
# 185_pm10            724
# 187_temperature    6173
# 187_humidity       6174
# 187_pressure       6197
# 187_pm1            6172
# 187_pm25           6172
# 187_pm10           6172
# 189_temperature     131
# 189_humidity        133
# 189_pressure        156
# 189_pm1             132
# 189_pm25            131
# 189_pm10            131
# 192_temperature     209
# 192_humidity        211
# 192_pressure        234
# 192_pm1             210
# 192_pm25            209
# 192_pm10            209
# 194_temperature     261
# 194_humidity        264
# 194_pressure        288
# 194_pm1             262
# 194_pm25            263
# 194_pm10            263
# 195_temperature    1308
# 195_humidity       1309
# 195_pressure       1333
# 195_pm1            1308
# 195_pm25           1308
# 195_pm10           1308
# 196_temperature     109
# 196_humidity        110
# 196_pressure       6863
# 196_pm1             108
# 196_pm25            108
# 196_pm10            108
# 201_temperature     186
# 201_humidity        188
# 201_pressure       6854
# 201_pm1             185
# 201_pm25            185
# 201_pm10            185
# 202_temperature     319
# 202_humidity        320
# 202_pressure        344
# 202_pm1             320
# 202_pm25            319
# 202_pm10            319
# 203_temperature    1587
# 203_humidity       1589
# 203_pressure       8593
# 203_pm1            1587
# 203_pm25           1587
# 203_pm10           1587
# 204_temperature      52
# 204_humidity         53
# 204_pressure         77
# 204_pm1              52
# 204_pm25             52
# 204_pm10             52
# 205_temperature    6066
# 205_humidity       6066
# 205_pressure       7183
# 205_pm1            6063
# 205_pm25           6062
# 205_pm10           6062
# 208_temperature     550
# 208_humidity        551
# 208_pressure        575
# 208_pm1             551
# 208_pm25            550
# 208_pm10            550
# 209_temperature     767
# 209_humidity        769
# 209_pressure        792
# 209_pm1             767
# 209_pm25            767
# 209_pm10            767
# 210_temperature     448
# 210_humidity        450
# 210_pressure        473
# 210_pm1             448
# 210_pm25            448
# 210_pm10            448
# 211_temperature    7144
# 211_humidity       7145
# 211_pressure       7169
# 211_pm1            7144
# 211_pm25           7144
# 211_pm10           7144
# 212_temperature       8
# 212_humidity          9
# 212_pressure         33
# 212_pm1               8
# 212_pm25              8
# 212_pm10              8
# 213_temperature    4622
# 213_humidity       4624
# 213_pressure       4552
# 213_pm1            4527
# 213_pm25           4527
# 213_pm10           4527
# 214_temperature      42
# 214_humidity         43
# 214_pressure         67
# 214_pm1              42
# 214_pm25             42
# 214_pm10             42
# 215_temperature     199
# 215_humidity        201
# 215_pressure        224
# 215_pm1             199
# 215_pm25            199
# 215_pm10            199
# 216_temperature    4074
# 216_humidity       4076
# 216_pressure       4097
# 216_pm1            4074
# 216_pm25           4074
# 216_pm10           4074
# 218_temperature      42
# 218_humidity         44
# 218_pressure         67
# 218_pm1              43
# 218_pm25             42
# 218_pm10             42
# 219_temperature     357
# 219_humidity        359
# 219_pressure        382
# 219_pm1             357
# 219_pm25            357
# 219_pm10            357
# 220_temperature      32
# 220_humidity         34
# 220_pressure         57
# 220_pm1              32
# 220_pm25             32
# 220_pm10             32
# 221_temperature      42
# 221_humidity         43
# 221_pressure         67
# 221_pm1              42
# 221_pm25             42
# 221_pm10             42
# 222_temperature      83
# 222_humidity         84
# 222_pressure        108
# 222_pm1              96
# 222_pm25             88
# 222_pm10             86
# 223_temperature      91
# 223_humidity         93
# 223_pressure        116
# 223_pm1              91
# 223_pm25             91
# 223_pm10             91
# 225_temperature     162
# 225_humidity        164
# 225_pressure        187
# 225_pm1             163
# 225_pm25            162
# 225_pm10            162
# 226_temperature      14
# 226_humidity         16
# 226_pressure         39
# 226_pm1              15
# 226_pm25             14
# 226_pm10             14
# 227_temperature    5667
# 227_humidity       5669
# 227_pressure       4418
# 227_pm1            4397
# 227_pm25           4394
# 227_pm10           4393
# 228_temperature      64
# 228_humidity         66
# 228_pressure         89
# 228_pm1              64
# 228_pm25             64
# 228_pm10             64
# 263_temperature     170
# 263_humidity        171
# 263_pressure        195
# 263_pm1             170
# 263_pm25            170
# 263_pm10            170
# 622_temperature    3278
# 622_humidity       3278
# 622_pressure       3014
# 622_pm1            3014
# 622_pm25           3014
# 622_pm10           3014
# 713_temperature    5810
# 713_humidity       5810
# 713_pressure       5562
# 713_pm1            5562
# 713_pm25           5562
# 713_pm10           5562
# 808_temperature    7495
# 808_humidity       7495
# 808_pressure       7446
# 808_pm1            7446
# 808_pm25           7446
# 808_pm10           7446
# 857_temperature    5946
# 857_humidity       5946
# 857_pressure       5940
# 857_pm1            5940
# 857_pm25           5940
# 857_pm10           5940
# 895_temperature    3150
# 895_humidity       3150
# 895_pressure       2256
# 895_pm1            2256
# 895_pm25           2256
# 895_pm10           2256
# dtype: int64

# %% [markdown]
# ## Null per sensor

# %%
for sensor_id in sensors:
    sensor_columns = get_sensor_columns(sensor_id)
    null_count = history[sensor_columns].isna().sum().sum()
    print(f"Sensor id: {sensor_id} null count: {null_count}")
# Out:
# Sensor id: 3 null count: 46263
# Sensor id: 263 null count: 1046
# Sensor id: 140 null count: 11970
# Sensor id: 142 null count: 39416
# Sensor id: 147 null count: 15123
# Sensor id: 808 null count: 44774
# Sensor id: 169 null count: 2014
# Sensor id: 170 null count: 824
# Sensor id: 171 null count: 501
# Sensor id: 172 null count: 14839
# Sensor id: 173 null count: 1205
# Sensor id: 174 null count: 7275
# Sensor id: 176 null count: 7136
# Sensor id: 177 null count: 7137
# Sensor id: 178 null count: 41591
# Sensor id: 179 null count: 7727
# Sensor id: 180 null count: 7018
# Sensor id: 181 null count: 7996
# Sensor id: 182 null count: 12197
# Sensor id: 183 null count: 9979
# Sensor id: 184 null count: 8343
# Sensor id: 185 null count: 10778
# Sensor id: 187 null count: 37060
# Sensor id: 189 null count: 814
# Sensor id: 192 null count: 1282
# Sensor id: 194 null count: 1601
# Sensor id: 195 null count: 7874
# Sensor id: 196 null count: 7406
# Sensor id: 201 null count: 7783
# Sensor id: 202 null count: 1941
# Sensor id: 203 null count: 16530
# Sensor id: 204 null count: 338
# Sensor id: 205 null count: 37502
# Sensor id: 713 null count: 33868
# Sensor id: 208 null count: 3327
# Sensor id: 209 null count: 4629
# Sensor id: 210 null count: 2715
# Sensor id: 211 null count: 42890
# Sensor id: 212 null count: 74
# Sensor id: 213 null count: 27379
# Sensor id: 214 null count: 278
# Sensor id: 215 null count: 1221
# Sensor id: 216 null count: 24469
# Sensor id: 857 null count: 35652
# Sensor id: 218 null count: 280
# Sensor id: 219 null count: 2169
# Sensor id: 220 null count: 219
# Sensor id: 221 null count: 278
# Sensor id: 222 null count: 545
# Sensor id: 223 null count: 573
# Sensor id: 225 null count: 1000
# Sensor id: 226 null count: 112
# Sensor id: 227 null count: 28938
# Sensor id: 228 null count: 411
# Sensor id: 622 null count: 18612
# Sensor id: 895 null count: 15324

# %% [markdown]
# Najlepszy sensor: __Sensor id: 212 null count: 74__

# %%
history.columns = pd.MultiIndex.from_tuples([(c.split('_')[0], c.split('_')[1]) for c in history.columns])
history.head()
# Out:
#                               3                                         140  \
#                     temperature humidity pressure pm1 pm25 pm10 temperature
# UTC time
# 2017-01-01 00:00:00         NaN      NaN      NaN NaN  NaN  NaN         NaN
# 2017-01-01 01:00:00         NaN      NaN      NaN NaN  NaN  NaN         NaN
# 2017-01-01 02:00:00         NaN      NaN      NaN NaN  NaN  NaN         NaN
# 2017-01-01 03:00:00         NaN      NaN      NaN NaN  NaN  NaN         NaN
# 2017-01-01 04:00:00         NaN      NaN      NaN NaN  NaN  NaN         NaN
#
#                                            ...      857                \
#                     humidity pressure pm1  ... pressure pm1 pm25 pm10
# UTC time                                   ...
# 2017-01-01 00:00:00      NaN      NaN NaN  ...      NaN NaN  NaN  NaN
# 2017-01-01 01:00:00      NaN      NaN NaN  ...      NaN NaN  NaN  NaN
# 2017-01-01 02:00:00      NaN      NaN NaN  ...      NaN NaN  NaN  NaN
# 2017-01-01 03:00:00      NaN      NaN NaN  ...      NaN NaN  NaN  NaN
# 2017-01-01 04:00:00      NaN      NaN NaN  ...      NaN NaN  NaN  NaN
#
#                             895
#                     temperature humidity pressure pm1 pm25 pm10
# UTC time
# 2017-01-01 00:00:00         NaN      NaN      NaN NaN  NaN  NaN
# 2017-01-01 01:00:00         NaN      NaN      NaN NaN  NaN  NaN
# 2017-01-01 02:00:00         NaN      NaN      NaN NaN  NaN  NaN
# 2017-01-01 03:00:00         NaN      NaN      NaN NaN  NaN  NaN
# 2017-01-01 04:00:00         NaN      NaN      NaN NaN  NaN  NaN
#
# [5 rows x 336 columns]

# %%
history.notna().groupby(pd.Grouper(freq='2D')).all().head()
# Out:
#                      3                                                140  \
#            temperature humidity pressure    pm1   pm25   pm10 temperature
# UTC time
# 2017-01-01       False    False    False  False  False  False       False
# 2017-01-03       False    False    False  False  False  False       False
# 2017-01-05       False    False    False  False  False  False       False
# 2017-01-07       False    False    False  False  False  False       False
# 2017-01-09       False    False    False  False  False  False       False
#
#                                      ...      857                       \
#            humidity pressure    pm1  ... pressure    pm1   pm25   pm10
# UTC time                             ...
# 2017-01-01    False    False  False  ...    False  False  False  False
# 2017-01-03    False    False  False  ...    False  False  False  False
# 2017-01-05    False    False  False  ...    False  False  False  False
# 2017-01-07    False    False  False  ...    False  False  False  False
# 2017-01-09    False    False  False  ...    False  False  False  False
#
#                    895
#            temperature humidity pressure    pm1   pm25   pm10
# UTC time
# 2017-01-01       False    False    False  False  False  False
# 2017-01-03       False    False    False  False  False  False
# 2017-01-05       False    False    False  False  False  False
# 2017-01-07       False    False    False  False  False  False
# 2017-01-09       False    False    False  False  False  False
#
# [5 rows x 336 columns]

# %% [markdown]
# ## Agregacja na przedziale czasowym

# %%
history_aggegated = history.groupby(pd.Grouper(freq='1D')).mean()
history_aggegated.head()
# Out:
#                      3                                         140           \
#            temperature humidity pressure pm1 pm25 pm10 temperature humidity
# UTC time
# 2017-01-01         NaN      NaN      NaN NaN  NaN  NaN         NaN      NaN
# 2017-01-02         NaN      NaN      NaN NaN  NaN  NaN         NaN      NaN
# 2017-01-03         NaN      NaN      NaN NaN  NaN  NaN         NaN      NaN
# 2017-01-04         NaN      NaN      NaN NaN  NaN  NaN         NaN      NaN
# 2017-01-05         NaN      NaN      NaN NaN  NaN  NaN         NaN      NaN
#
#                          ...      857                       895           \
#            pressure pm1  ... pressure pm1 pm25 pm10 temperature humidity
# UTC time                 ...
# 2017-01-01      NaN NaN  ...      NaN NaN  NaN  NaN         NaN      NaN
# 2017-01-02      NaN NaN  ...      NaN NaN  NaN  NaN         NaN      NaN
# 2017-01-03      NaN NaN  ...      NaN NaN  NaN  NaN         NaN      NaN
# 2017-01-04      NaN NaN  ...      NaN NaN  NaN  NaN         NaN      NaN
# 2017-01-05      NaN NaN  ...      NaN NaN  NaN  NaN         NaN      NaN
#
#
#            pressure pm1 pm25 pm10
# UTC time
# 2017-01-01      NaN NaN  NaN  NaN
# 2017-01-02      NaN NaN  NaN  NaN
# 2017-01-03      NaN NaN  NaN  NaN
# 2017-01-04      NaN NaN  NaN  NaN
# 2017-01-05      NaN NaN  NaN  NaN
#
# [5 rows x 336 columns]

# %%
history__isna_aggegated_grouped_by_columns = history_aggegated.isna().groupby(level=[0], axis=1).all()
history__isna_aggegated_grouped_by_columns.head()
# Out:
#              140    142    147    169    170    171    172    173    174  \
# 2017-01-01  True  False  False  False  False  False  False  False  False
# 2017-01-02  True  False  False  False  False  False  False  False  False
# 2017-01-03  True  False  False  False  False  False  False  False  False
# 2017-01-04  True   True  False  False  False  False  False  False  False
# 2017-01-05  True  False  False  False  False  False  False  False  False
#
#               176  ...    226    227    228    263     3   622   713   808  \
# 2017-01-01  False  ...  False  False  False  False  True  True  True  True
# 2017-01-02  False  ...  False  False  False  False  True  True  True  True
# 2017-01-03  False  ...  False  False  False  False  True  True  True  True
# 2017-01-04  False  ...  False  False  False  False  True  True  True  True
# 2017-01-05  False  ...  False  False  False  False  True  True  True  True
#
#              857   895
# 2017-01-01  True  True
# 2017-01-02  True  True
# 2017-01-03  True  True
# 2017-01-04  True  True
# 2017-01-05  True  True
#
# [5 rows x 56 columns]

# %%
history__isna_aggegated_grouped_by_columns['3']
# Out:
# 2017-01-01     True
# 2017-01-02     True
# 2017-01-03     True
# 2017-01-04     True
# 2017-01-05     True
# 2017-01-06     True
# 2017-01-07     True
# 2017-01-08     True
# 2017-01-09     True
# 2017-01-10     True
# 2017-01-11     True
# 2017-01-12     True
# 2017-01-13     True
# 2017-01-14     True
# 2017-01-15     True
# 2017-01-16     True
# 2017-01-17    False
# 2017-01-18    False
# 2017-01-19    False
# 2017-01-20    False
# 2017-01-21    False
# 2017-01-22    False
# 2017-01-23    False
# 2017-01-24    False
# 2017-01-25    False
# 2017-01-26    False
# 2017-01-27    False
# 2017-01-28    False
# 2017-01-29    False
# 2017-01-30    False
# 2017-01-31    False
# 2017-02-01    False
# 2017-02-02    False
# 2017-02-03    False
# 2017-02-04    False
# 2017-02-05    False
# 2017-02-06    False
# 2017-02-07    False
# 2017-02-08    False
# 2017-02-09    False
# 2017-02-10    False
# 2017-02-11    False
# 2017-02-12    False
# 2017-02-13    False
# 2017-02-14    False
# 2017-02-15    False
# 2017-02-16    False
# 2017-02-17    False
# 2017-02-18    False
# 2017-02-19    False
# 2017-02-20    False
# 2017-02-21    False
# 2017-02-22    False
# 2017-02-23    False
# 2017-02-24    False
# 2017-02-25    False
# 2017-02-26    False
# 2017-02-27    False
# 2017-02-28    False
# 2017-03-01    False
# 2017-03-02    False
# 2017-03-03    False
# 2017-03-04    False
# 2017-03-05    False
# 2017-03-06    False
# 2017-03-07    False
# 2017-03-08    False
# 2017-03-09    False
# 2017-03-10    False
# 2017-03-11     True
# 2017-03-12     True
# 2017-03-13     True
# 2017-03-14     True
# 2017-03-15     True
# 2017-03-16     True
# 2017-03-17     True
# 2017-03-18     True
# 2017-03-19     True
# 2017-03-20     True
# 2017-03-21     True
# 2017-03-22     True
# 2017-03-23     True
# 2017-03-24     True
# 2017-03-25     True
# 2017-03-26     True
# 2017-03-27     True
# 2017-03-28     True
# 2017-03-29     True
# 2017-03-30     True
# 2017-03-31     True
# 2017-04-01     True
# 2017-04-02     True
# 2017-04-03     True
# 2017-04-04     True
# 2017-04-05     True
# 2017-04-06     True
# 2017-04-07     True
# 2017-04-08     True
# 2017-04-09     True
# 2017-04-10     True
# 2017-04-11     True
# 2017-04-12     True
# 2017-04-13     True
# 2017-04-14     True
# 2017-04-15     True
# 2017-04-16     True
# 2017-04-17     True
# 2017-04-18     True
# 2017-04-19     True
# 2017-04-20     True
# 2017-04-21     True
# 2017-04-22     True
# 2017-04-23     True
# 2017-04-24     True
# 2017-04-25     True
# 2017-04-26     True
# 2017-04-27     True
# 2017-04-28     True
# 2017-04-29     True
# 2017-04-30     True
# 2017-05-01     True
# 2017-05-02     True
# 2017-05-03     True
# 2017-05-04     True
# 2017-05-05     True
# 2017-05-06     True
# 2017-05-07     True
# 2017-05-08     True
# 2017-05-09     True
# 2017-05-10     True
# 2017-05-11     True
# 2017-05-12     True
# 2017-05-13     True
# 2017-05-14     True
# 2017-05-15     True
# 2017-05-16     True
# 2017-05-17     True
# 2017-05-18     True
# 2017-05-19     True
# 2017-05-20     True
# 2017-05-21     True
# 2017-05-22     True
# 2017-05-23     True
# 2017-05-24     True
# 2017-05-25     True
# 2017-05-26     True
# 2017-05-27     True
# 2017-05-28     True
# 2017-05-29     True
# 2017-05-30     True
# 2017-05-31     True
# 2017-06-01     True
# 2017-06-02     True
# 2017-06-03     True
# 2017-06-04     True
# 2017-06-05     True
# 2017-06-06     True
# 2017-06-07     True
# 2017-06-08     True
# 2017-06-09     True
# 2017-06-10     True
# 2017-06-11     True
# 2017-06-12     True
# 2017-06-13     True
# 2017-06-14     True
# 2017-06-15     True
# 2017-06-16     True
# 2017-06-17     True
# 2017-06-18     True
# 2017-06-19     True
# 2017-06-20     True
# 2017-06-21     True
# 2017-06-22     True
# 2017-06-23     True
# 2017-06-24     True
# 2017-06-25     True
# 2017-06-26     True
# 2017-06-27     True
# 2017-06-28     True
# 2017-06-29     True
# 2017-06-30     True
# 2017-07-01     True
# 2017-07-02     True
# 2017-07-03     True
# 2017-07-04     True
# 2017-07-05     True
# 2017-07-06     True
# 2017-07-07     True
# 2017-07-08     True
# 2017-07-09     True
# 2017-07-10     True
# 2017-07-11     True
# 2017-07-12     True
# 2017-07-13     True
# 2017-07-14     True
# 2017-07-15     True
# 2017-07-16     True
# 2017-07-17     True
# 2017-07-18     True
# 2017-07-19     True
# 2017-07-20     True
# 2017-07-21     True
# 2017-07-22     True
# 2017-07-23     True
# 2017-07-24     True
# 2017-07-25     True
# 2017-07-26     True
# 2017-07-27     True
# 2017-07-28     True
# 2017-07-29     True
# 2017-07-30     True
# 2017-07-31     True
# 2017-08-01     True
# 2017-08-02     True
# 2017-08-03     True
# 2017-08-04     True
# 2017-08-05     True
# 2017-08-06     True
# 2017-08-07     True
# 2017-08-08     True
# 2017-08-09     True
# 2017-08-10     True
# 2017-08-11     True
# 2017-08-12     True
# 2017-08-13     True
# 2017-08-14     True
# 2017-08-15     True
# 2017-08-16     True
# 2017-08-17     True
# 2017-08-18     True
# 2017-08-19     True
# 2017-08-20     True
# 2017-08-21     True
# 2017-08-22     True
# 2017-08-23     True
# 2017-08-24     True
# 2017-08-25     True
# 2017-08-26     True
# 2017-08-27     True
# 2017-08-28     True
# 2017-08-29     True
# 2017-08-30     True
# 2017-08-31     True
# 2017-09-01     True
# 2017-09-02     True
# 2017-09-03     True
# 2017-09-04     True
# 2017-09-05     True
# 2017-09-06     True
# 2017-09-07     True
# 2017-09-08     True
# 2017-09-09     True
# 2017-09-10     True
# 2017-09-11     True
# 2017-09-12     True
# 2017-09-13     True
# 2017-09-14     True
# 2017-09-15     True
# 2017-09-16     True
# 2017-09-17     True
# 2017-09-18     True
# 2017-09-19     True
# 2017-09-20     True
# 2017-09-21     True
# 2017-09-22     True
# 2017-09-23     True
# 2017-09-24     True
# 2017-09-25     True
# 2017-09-26     True
# 2017-09-27     True
# 2017-09-28     True
# 2017-09-29     True
# 2017-09-30     True
# 2017-10-01     True
# 2017-10-02     True
# 2017-10-03     True
# 2017-10-04     True
# 2017-10-05     True
# 2017-10-06     True
# 2017-10-07     True
# 2017-10-08     True
# 2017-10-09     True
# 2017-10-10     True
# 2017-10-11     True
# 2017-10-12     True
# 2017-10-13     True
# 2017-10-14     True
# 2017-10-15     True
# 2017-10-16     True
# 2017-10-17     True
# 2017-10-18     True
# 2017-10-19     True
# 2017-10-20     True
# 2017-10-21     True
# 2017-10-22     True
# 2017-10-23     True
# 2017-10-24     True
# 2017-10-25     True
# 2017-10-26     True
# 2017-10-27     True
# 2017-10-28     True
# 2017-10-29     True
# 2017-10-30     True
# 2017-10-31     True
# 2017-11-01     True
# 2017-11-02     True
# 2017-11-03     True
# 2017-11-04     True
# 2017-11-05     True
# 2017-11-06     True
# 2017-11-07     True
# 2017-11-08     True
# 2017-11-09     True
# 2017-11-10     True
# 2017-11-11     True
# 2017-11-12     True
# 2017-11-13     True
# 2017-11-14     True
# 2017-11-15     True
# 2017-11-16     True
# 2017-11-17     True
# 2017-11-18     True
# 2017-11-19     True
# 2017-11-20     True
# 2017-11-21     True
# 2017-11-22     True
# 2017-11-23     True
# 2017-11-24     True
# 2017-11-25     True
# 2017-11-26     True
# 2017-11-27     True
# 2017-11-28     True
# 2017-11-29     True
# 2017-11-30     True
# 2017-12-01     True
# 2017-12-02     True
# 2017-12-03     True
# 2017-12-04     True
# 2017-12-05     True
# 2017-12-06     True
# 2017-12-07     True
# 2017-12-08     True
# 2017-12-09     True
# 2017-12-10     True
# 2017-12-11     True
# 2017-12-12     True
# 2017-12-13     True
# 2017-12-14     True
# 2017-12-15     True
# 2017-12-16     True
# 2017-12-17     True
# 2017-12-18     True
# 2017-12-19     True
# 2017-12-20     True
# 2017-12-21     True
# 2017-12-22     True
# 2017-12-23     True
# 2017-12-24     True
# 2017-12-25     True
# Name: 3, dtype: bool

# %%
import numpy as np
import matplotlib.pyplot as plt


for n, col in enumerate(df.columns): 
    df[col] = df[col]*n
    df.plot(lw=10, legend=False)
plt.yticks(pd.np.arange(len(df.columns)), df.columns)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-194-bebaf00928ba> in <module>
#      53
#      54
# ---> 55 survey(history__isna_aggegated_grouped_by_columns, category_names)
#      56 plt.show()
#
# <ipython-input-194-bebaf00928ba> in survey(results, category_names)
#      36
#      37     for i, (colname, color) in enumerate(zip(category_names, category_colors)):
# ---> 38         widths = data[:, i]
#      39         starts = data_cum[:, i] - widths
#      40         ax.barh(labels, widths, left=starts, height=0.5,
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2644                 )
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#    2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key

# %% [markdown]
# ## Wizualizacja

# %%
import folium
import pandas as pd

sensor_locations = pd.read_csv('sensor_locations.csv', index_col="id")
sensor_locations.head()
# Out:
#       latitude  longitude
# id
# 3    50.057748  19.961375
# 140  50.057747  19.961374
# 142  50.084816  19.878066
# 147  50.048924  19.962262
# 169  50.048699  20.101569

# %%
center = (sensor_locations.mean()['latitude'], sensor_locations.mean()['longitude'])
center
# Out:
# (50.059703410714285, 19.941391785714284)

# %%
sensor_locations.loc[140]
# Out:
# latitude     50.057747
# longitude    19.961374
# Name: 140, dtype: float64

# %%
krakow_map = folium.Map(location=center, zoom_start=12)

for index, sensor_location in sensor_locations.iterrows():
    location = [sensor_location['latitude'], sensor_location['longitude']]
    #print(location)
    folium.Marker(location, popup = f'id: {index}\n latitude: {sensor_location["latitude"]}\n longitude: {sensor_location["longitude"]}').add_to(krakow_map)
    
krakow_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_84b651dfee2648a1aa67d8802f9faffb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_84b651dfee2648a1aa67d8802f9faffb%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_84b651dfee2648a1aa67d8802f9faffb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_84b651dfee2648a1aa67d8802f9faffb%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B50.059703410714285%2C%2019.941391785714284%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
def show_sensor_by_id(sensor_id: str):
    krakow_map = folium.Map(location=center, zoom_start=12)
    location = sensor_locations.loc[sensor_id]["latitude"], sensor_locations.loc[sensor_id]["longitude"]
    folium.Marker(location, popup = f'id: {sensor_id}\n latitude: {location[0]}\n longitude: {location[1]}').add_to(krakow_map)
    return krakow_map

show_sensor_by_id(212)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1a3347ef03fe446bae44a6ea0e65a5ce%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1a3347ef03fe446bae44a6ea0e65a5ce%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1a3347ef03fe446bae44a6ea0e65a5ce%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1a3347ef03fe446bae44a6ea0e65a5ce%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B50.059703410714285%2C%2019.941391785714284%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Done
#
# - Które sensory mają dużo pomiarów?
# - Agregacja na przedziale czasowym - feature vector
# - Wizualizacja sensorów
#
# ## Pytania, dalsze cele
#
# ### Wektor danych uczących, target
# #### Feature verctor
# Bazując na uśrednionych danych z 1 dnia, 2 dni, Pon-piątek
#
# #### Target
# Przewidujemy stan pm1, pm10, pm25 na jutro, na najbliższy tydzień, na weekend.
#
#
# ### Baseline model - regresja
# Prosty model predykcyjny dla jednego sensora (zawierającego najwiecej danych).
# Czy sensor potrafi przewidywać swoje pomiary?
#
# Bierzemy dane z jednego dnia (pogoda + pm), przewidujemy pm następnego dnia.
#
#
#
# ### Definicja stanu powietrza w całym Krakowie
# - uśrednione wartości (pm1, pm10, pm25) ze wszystkich dostępnych sensorów?
# - wykrycie/odrzucenie sensorów - outlierów
# - np. sonsor przy dużej ulicy
#
#
# ### Model predykcyjny w oparciu o zagregowane dane ze wszystkich/dostępnych sensorów.
# - Czy bazując na danych z wielu sensorów da się przewidywać ogólne/średnie stężenie pyłów w Krakowie?
# - Czy istnieje jeden/kilka sensorów które najlepiej przewidują ogólne/średnie stężenie pyłów w Krakowie?
#
# ### Uzupełnienie danych brakujących
# - uśrednienie z istniejących sensorów
# - info o pogodzie z zewnętrznego żródła
#
#
# ### Uwagi
# Wszystkie kolumny są ordinal, nie ma potrzeby korzystania z one-hot encoding.
